# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('movies_train.csv')
df
# col_discription = ["제목", "배급사", "장르", "개봉일", "상영시간", "상영등급", "감독이름", "감독이전작품평균관객수", "감독 이전작품수", "스텝수", "주연배우수","관객수"]
# pd.DataFrame(col_discription,index = df.columns)
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
df
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
# 결측치
import missingno as msno
msno.matrix(df)
df.isna().sum()
# Out:
# title               0
# distributor         0
# genre               0
# release_time        0
# time                0
# screening_rat       0
# director            0
# dir_prev_bfnum    330
# dir_prev_num        0
# num_staff           0
# num_actor           0
# box_off_num         0
# dtype: int64

# %%
# 결측치가 있는 데이터의 감독은?
# 결측치 주변 데이터를 확인 - 살릴지 죽일지
# 결측치가 생긴 원인 파악? - 이전 영화가 없는 감독이면...정상적인 데이터
df[df['dir_prev_bfnum'].isna()]['director'].unique()
df.fillna(0, inplace=True)
df
# Out:
#          title   distributor genre release_time  time screening_rat director  \
# 0       개들의 전쟁      롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 1         내부자들        (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 2    은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 3     나는 공무원이다        (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 4         불량남녀  쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
# ..         ...           ...   ...          ...   ...           ...      ...
# 595         해무        (주)NEW   드라마   2014-08-13   111      청소년 관람불가      심성보
# 596       파파로티        (주)쇼박스   드라마   2013-03-14   127       15세 관람가      윤종찬
# 597      살인의 강     (주)마운틴픽쳐스    공포   2010-09-30    99      청소년 관람불가      김대현
# 598     악의 연대기     CJ 엔터테인먼트   느와르   2015-05-14   102       15세 관람가      백운학
# 599        베를린     CJ 엔터테인먼트    액션   2013-01-30   120       15세 관람가      류승완
#
# ...

# %%
df.describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor  \
# count  600.000000    6.000000e+02    600.000000  600.000000  600.000000
# mean   100.863333    4.726993e+05      0.876667  151.118333    3.706667
# std     18.097528    1.309474e+06      1.183409  165.654671    2.446889
# min     45.000000    0.000000e+00      0.000000    0.000000    0.000000
# 25%     89.000000    0.000000e+00      0.000000   17.000000    2.000000
# 50%    100.000000    0.000000e+00      0.000000   82.500000    3.000000
# 75%    114.000000    3.761416e+05      2.000000  264.000000    4.000000
# max    180.000000    1.761531e+07      5.000000  869.000000   25.000000
#
#         box_off_num
# count  6.000000e+02
# mean   7.081818e+05
# std    1.828006e+06
# min    1.000000e+00
# 25%    1.297250e+03
# 50%    1.259100e+04
# 75%    4.798868e+05
# max    1.426277e+07

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
# 왼쪽으로 치우쳐져서 오른쪽 꼬리가 긴 형태(대부분의  관객수는 5만명대에 형성되어 있고), outlier가 많고 크자 즉,, 히트작의 영향이 크다

# %%
# 관객수 box_off_num과 높은  상관관계를 가지는 변수를 찾
corr = df.corr(method='spearman', numeric_only=True)
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
# 관객수는 상영시간과 스텝수 높은 상관관계 - 상영시간이 길수록 관객수가 증가하는 경향

# %%
df.describe(include=['object', 'category'])
# Out:
#          title distributor genre release_time screening_rat director
# count      600         600   600          600           600      600
# unique     600         169    12          330             4      472
# top     개들의 전쟁   CJ 엔터테인먼트   드라마   2015-08-13      청소년 관람불가      홍상수
# freq         1          54   221            6           204        7

# %%
print(df['box_off_num'].corr(df['time'])) 
print(df['box_off_num'].corr(df['time'],method='spearman'))
# Out:
# 0.44145239154082855
# 0.6094410730461675

# %% [markdown]
# 상관계수
# ```
# 상관계수 두 변수간의 관계강도와 방향을 측정
# 피어슨 상관계수 : 선형관계를 측정, 데이터가 정규분포따르고 선형일때
# 스피어만 : 순위기반, 비선형관계나 또는 순서데이터(예: 순위, 크기)
# ```
# ![image.png](attachment:image.png)
# ```
# 피어슨  상관계수
# 두변수 x,y의 공분산을 각 변수의 표준편차로 나눈 값
# 1. 각 변수의 평균 계산
# 2. 각 데이터 포인트에서 평균을 뺀 값을 계산 - 편차
# 3. 편차들의 곱 합 계산(공분산 분자 계산)
# 4. 각 편차 제곱합 계산
# 5. 분자 / (분모의 제곱근)으로 계산
# ```
# 데이터가 연속적이고 선형적일때 사용

# %% [markdown]
# 스피어만 상관계수
# ```
# 두 변수의 순위(rank)를  변환한 후  적용 - 실제 데이터 값 대신에 순위를 사용
# ```
# ![image.png](attachment:image.png)
# ```
# 1. 각 변수 x와 y의 데이터를 오름차순으로 정렬해 순위 부여(동점 평균순위 사용)
# 2. 각 데이터 쌍의 순위 차이(di = rankx - ranky)
# 3. di^2합 계산
# 4. 1 - ( di^2합 계산 / n(n^2-1))
# ```
# 이상치나 비선형 관계에 적합

# %%
# x(온도) y(아이스크림 판매량)
import numpy as np
x=np.array([20,25,30,36,40])
y=np.array([10,15,20,25,30])

x_mean = x.mean()
y_mean = y.mean()

# x y의 편차
x_ = x - x_mean
y_ = y - y_mean
# 편차 곱 합
np.sum(x_ * y_)
# x 편차 제곱 합
np.sum(x_ ** 2)
# 분모
np.sqrt(np.sum(x_ ** 2) * np.sum(y_ ** 2))


np.sum(x_ * y_) / np.sqrt(np.sum(x_ ** 2) * np.sum(y_ ** 2))
# Out:
# np.float64(0.9986570737346456)

# %%
import matplotlib.pyplot as plt
x=np.array([25,27,30,36,40])
y=np.array([20,10,20,15,18])
plt.scatter(x,y)
x_mean = x.mean()
y_mean = y.mean()

# x y의 편차
x_ = x - x_mean
y_ = y - y_mean
# 편차 곱 합
np.sum(x_ * y_)
# x 편차 제곱 합
np.sum(x_ ** 2)
# 분모
np.sqrt(np.sum(x_ ** 2) * np.sum(y_ ** 2))


np.sum(x_ * y_) / np.sqrt(np.sum(x_ ** 2) * np.sum(y_ ** 2))
# Out:
# np.float64(0.06805597006380865)

# %%
# 스피어만 상관계수
x=np.array([25,27,30,36,40])
y=np.array([20,10,20,15,18])

rank_x =  [1,2,3,4,5]
rank_y = [1,2,3,4,5]
# 순위 차이
di = [0,0,0,0,0]
# 분자 = 0
1 - (6 * np.sum(np.array(di)**2)) / (5 * (5**2 -1))
# Out:
# np.float64(1.0)
